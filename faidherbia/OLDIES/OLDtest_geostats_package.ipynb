# %%
import mask_data


#Le dossier dans lequel je mets les geotifs
geotif_path="/user/rfernandez/datamansour/..."

#Le dossier dans lequel j'ai enregistré les shapefile
shapefile_path="/user/rfernandez/datamansour/..."

#D'autres définitions

# %%
# Appliquer les shapefiles pour masquer les images, et ne selectionner que les parcelles, 
# ou que les zones d'influence des faidherbia

save_results=True
appeler_ici_la_fonction_qu_fait_le_masquage(geotif_path,shapefile_path)

for i in range(Nf):
    #Faire quelque chose


    if(save_results):
    #Enregistrer quelque chose
